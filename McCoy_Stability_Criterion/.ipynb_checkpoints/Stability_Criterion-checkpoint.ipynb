# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
from extract_data import get_column
from utility import get_data, get_spin

# %% [markdown]
# #### Approximating a Flight Profile
# All of these calculations are dependent on having accurate time and acceleration data. From there we can find the velocity, position, air density - everything we need to figure out how fast we need to spin save the actual rocket geometry. For now we can get this by plugging in data from Thunderguppy. Ideally, we would be able to just use the thrust curve of the motor (H550 or N5800) but I haven't found that data. For now just plug in a text file with Guppy data from a successful launch that went mostly up.

# %%
file = open("15-2-2020-trim.txt")
time, accel = get_column(file, 2)
time = np.asarray(time)
accel = np.asarray(accel) + 9.8

# %% [markdown]
# #### Get Start Time
# The lines below are to help you get the start time for the launch. Guppy records continuously so a lot of unnecessary data is collected which would slow down the sim. We could get this number computationally but this is way easier :) The goal is to zero in on the start and end times of the launch.

# %% [markdown]
# | Column Code | Value |
# | ------ | ----- |
# | 0 | time |
# | 1 | adxl x-accel |
# | 2 | adxl y-accel |
# | 3 | axl1 z-accel |
# | 4 | bmi x-accel |
# | 5 | bmi y-accel |
# | 6 | bmi z-accel |

# %%
start = 0
end = len(accel)
plt.plot(time[start:end], accel[start:end])
plt.show()
while True:    
    start = np.argmax(time > input("Approximately when does ignition occur: "))
    end = np.argmax(time > input("When did the rocket touch back down: "))
    
    plt.plot(time[start:end], accel[start:end])
    plt.show()
    
    if raw_input("Press q to stop: ") == 'q':
        break        
time = time[start:end] - time[start]
# time = np.asarray([x - time[start] for x in time[start:end]])
accel = accel[start:end] * -1
# Out:
# Approximately when does ignition occur: 19894
# When did the rocket touch back down: 19905
# Press q to stop: q

# %% [markdown]
# #### Model Environment
# Acceleration data is used to get velocity, altitude, and air density. Check the graphs for accuracy
# <br>
# <div align='middle'>
#     $v(t)=\int_{start}^{end}{a(t)dt} + v_0$
#     <br>
#     $x(t)=\int_{start}^{end}{x(t)dt} + x_0$
#     <br>
#     $\rho=\rho_b\bigg[\frac{T_b}{T_b+L_b*(x(t)-x_0)}\bigg]^{1+\frac{g_0\cdot M}{R\cdot L_b}}$

# %%
vel, altit, rho = get_data(time, accel)

plt.subplot(311)
plt.xlabel('Time (s)')
plt.ylabel('Velocity (m/s)')
plt.plot(time, vel, label='')

plt.subplot(313)
plt.plot(time, altit, label='altitude', color='tab:blue')
plt.xlabel('Time (s)')
plt.ylabel('Altitude (m)')
plt2 = plt.twinx()
plt2.set_ylabel('Air Density(kg/m^3)')
plt.plot(time, rho, label='air density', color='tab:red')

plt.show()
# Out:
# utility.py:14: RuntimeWarning: divide by zero encountered in double_scalars
#   rho.extend([1.225 * (288.15 / (288.15 + -0.0065 * x ** (1 + (9.8 * 0.02896) / (8.3145 * -0.0065)))) for x in x_pos[:trop_x]])

# %% [markdown]
# #### Rocket Parameters
# We also need to know a few properties of the specific rocket in quesiton. An excel file is available in this folder with slots for the parameters in quesition. Save is a csv and copy the name below

# %%
min_spin = get_spin(vel, rho, "Marvin.csv")
# Out:
# utility.py:34: RuntimeWarning: invalid value encountered in sqrt
#   return [vel[i] / rocket['I_x'] * np.sqrt(2 * rho[i] * rocket['I_y'] * rocket['Surface Area'] * rocket['Calipers'] * rocket['Diameter']) for i in range(len(vel))]

# %% [markdown]
# #### Done!
# Using all of the information above we can calculate a *minimum* threshold for spin stability and compare it to the values recorded
# <div align='middle'>
#     $p>\frac{V}{I_x}\sqrt{2\rho SdC_{M_\alpha}I_y}$

# %%
plt.xlabel('Time (s)')
plt.ylabel('Spin Rate (rad/s)')
plt.plot(time, min_spin)
